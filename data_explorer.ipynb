# %%
from classify_common import load_metadata, load_image

# %%
from glob import glob
from pathlib import Path

paths =[path.stem for path in sorted(list(Path('./test_images/test_images/').glob('*.jpg')))]
paths
# Out:
# ['test_000001',
#  'test_000002',
#  'test_000003',
#  'test_000004',
#  'test_000005',
#  'test_000006',
#  'test_000007',
#  'test_000008',
#  'test_000009',
#  'test_000010',
#  'test_000011',
#  'test_000012',
#  'test_000013',
#  'test_000014',
#  'test_000015',
#  'test_000016',
#  'test_000017',
#  'test_000018',
#  'test_000019',
#  'test_000020',
#  'test_000021',
#  'test_000022',
#  'test_000023',
#  'test_000024',
#  'test_000025',
#  'test_000026',
#  'test_000027',
#  'test_000028',
#  'test_000029',
#  'test_000030',
#  'test_000031',
#  'test_000032',
#  'test_000033',
#  'test_000034',
#  'test_000035',
#  'test_000036',
#  'test_000037',
#  'test_000038',
#  'test_000039',
#  'test_000040',
#  'test_000041',
#  'test_000042',
#  'test_000043',
#  'test_000044',
#  'test_000045',
#  'test_000046',
#  'test_000047',
#  'test_000048',
#  'test_000049',
#  'test_000050',
#  'test_000051',
#  'test_000052',
#  'test_000053',
#  'test_000054',
#  'test_000055',
# ...
